# %%
pip install pymupdf pandas
# Out:
# ...
#   Using cached pandas-2.3.1-cp313-cp313-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached numpy-2.3.2-cp313-cp313-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/18.7 MB ? eta -:--:--
#    -- ------------------------------------- 1.3/18.7 MB 6.7 MB/s eta 0:00:03
#    ------ --------------------------------- 2.9/18.7 MB 8.1 MB/s eta 0:00:02
#    ----------- ---------------------------- 5.2/18.7 MB 8.9 MB/s eta 0:00:02
#    --------------- ------------------------ 7.3/18.7 MB 9.3 MB/s eta 0:00:02
#    -------------------- ------------------- 9.7/18.7 MB 9.6 MB/s eta 0:00:01
#    -------------------------- ------------- 12.3/18.7 MB 10.0 MB/s eta 0:00:01
#    ------------------------------ --------- 14.4/18.7 MB 10.0 MB/s eta 0:00:01
#    --------------------------------- ------ 15.7/18.7 MB 9.6 MB/s eta 0:00:01
# ...
